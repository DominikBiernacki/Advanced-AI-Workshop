# %% [markdown]
# ## Zagadki
#
# https://github.com/OlimpiadaAI/I-OlimpiadaAI/blob/main/first_stage/riddles/zagadki.ipynb

# %% [markdown]
# ## Ekstrakcja Źródeł
#
# https://github.com/OlimpiadaAI/II-OlimpiadaAI/blob/main/2_etap/ekstrakcja_zrodel/ekstrakcja_zrodel.ipynb
