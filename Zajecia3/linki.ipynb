# %% [markdown]
# ZADANIE Z OAI (Podobno trudne) - Na CNN ale nie tylko
#
# https://github.com/OlimpiadaAI/II-OlimpiadaAI/tree/main/1_etap/1_maszynka_do_liczenia_monet

# %% [markdown]
# Też zadanie z OAI (Chyba łatwiejsze) - Na CNN
#
# https://github.com/OlimpiadaAI/I-OlimpiadaAI/blob/main/first_stage/imbalanced_classification

# %% [markdown]
# Zadanie z OAI na m.in. Word2Vec
#
# https://github.com/OlimpiadaAI/II-OlimpiadaAI/blob/main/2_etap/ekstrakcja_zrodel
