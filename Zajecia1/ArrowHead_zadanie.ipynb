# %%
# !pip install tslearn

# %%
from tslearn.datasets import UCR_UEA_datasets

ucr = UCR_UEA_datasets()
X_train, y_train, X_test, y_test = ucr.load_dataset("ArrowHead")
X_train = X_train.squeeze()
X_test = X_test.squeeze()

# %% [markdown]
# ## Zadania

# %% [markdown]
# ### Analiza zbioru danych

# %% [markdown]
# Przeanalizuj zbiór danych - odpowiedz na następujące pytania:
# 1) Ile jest różnych klas i jak są oznaczone?
# 2) Jaki wymiar mają dane?
# 3) Jaki zakres mają dane (najmniejsza i największa wartość)?

# %% [markdown]
# Zobacz jak wyglądają dane na wykresie. Poniżej znajduje się kod rysujący wykres pierwszej obserwacji ze zbioru. Zmodyfikuj go tak, aby wyświetlić wykres wszystkich obserwacji ze zbioru treningowego. Dodatkowo spraw, aby obserwacje należące do tej samej klasy miały ten sam kolor, a te należące do różnych klas - inny.

# %%
import matplotlib.pyplot as plt

plt.plot(X_train[0], color='blue')
plt.show()

# %% [markdown]
# ### Klasyfikacja

# %% [markdown]
# Zobacz jak na tym zbiorze radzi sobie klasyfikator kNN. Poeksperymentuj z parametrem k.

# %% [markdown]
# Zobacz teraz jak działa klasyfikator Random Forest. Poeksperymentuj z parametrami i zobacz czy i jak wpływają na wyniki.

# %% [markdown]
# ## Na koniec prawdziwe zadanie z Olimpiady AI

# %% [markdown]
# https://github.com/OlimpiadaAI/II-OlimpiadaAI/blob/main/1_etap/3_wykrywanie_zaburzen_sygnalu_ekg/3_wykrywanie_zaburzen_sygnalu_ekg.ipynb
