# %% [markdown]
# ## Rozkład nienormalny
#
# https://github.com/OlimpiadaAI/II-OlimpiadaAI/tree/main/2_etap/rozklad_nienormalny

# %% [markdown]
# ## Kredytobranie
#
# https://github.com/OlimpiadaAI/II-OlimpiadaAI/tree/main/2_etap/kredytobranie

# %% [markdown]
# ## Self-Supervised Learning
#
# https://github.com/OlimpiadaAI/I-OlimpiadaAI/tree/main/final_stage/self_supervised_learning

# %% [markdown]
# ## Anomaly detection
#
# https://github.com/OlimpiadaAI/I-OlimpiadaAI/tree/main/final_stage/anomaly_detection
